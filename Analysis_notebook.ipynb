# %%
from data_collector import get_imf_employment_data, get_imf_gdp_data

imf_raw = get_imf_employment_data()
gdp_raw = get_imf_gdp_data()

# %%
countries = list(gdp_raw.COUNTRY.unique())
countries

brazil_gdp = gdp_raw.loc[lambda x: x['COUNTRY'] == 'BRA', ['TIME_PERIOD', 'OBS_VALUE']]
brazil_gdp

# %%
#imf_raw.columns
gdp_raw.columns
# Out:
# Index(['STRUCTURE[;]', 'STRUCTURE_ID', 'ACTION', 'COUNTRY', 'INDICATOR',
#        'PRICE_TYPE', 'S_ADJUSTMENT', 'TYPE_OF_TRANSFORMATION', 'FREQUENCY',
#        'TIME_PERIOD', 'OBS_VALUE', 'SCALE', 'PRECISION', 'DECIMALS_DISPLAYED',
#        'NA_STO', 'ACTIVITY', 'SECTOR', 'ACCOUNTS', 'INDEX_TYPE', 'PRICES',
#        'VINDEX_TYPE', 'TRANSFORMATION', 'UNIT', 'DERIVATION_TYPE', 'OVERLAP',
#        'IFS_FLAG', 'REFERENCE_PERIOD_REPORTED', 'COMPUTATIONAL_NOTE',
#        'CONFIDENTIALITY_STATUS', 'DOI', 'AUTHOR', 'PUBLISHER[]',
#        'DEPARTMENT[]', 'CONTACT_POINT', 'TOPIC[]', 'TOPIC_DATASET[]',
#        'LANGUAGE[]', 'PUBLICATION_DATE', 'UPDATE_DATE', 'METHODOLOGY[]',
#        'ACCESS_SHARING_LEVEL[]', 'SECURITY_CLASSIFICATION[]', 'SOURCE[]',
#        'KEY_INDICATOR', 'SERIES_NAME', 'FULL_DESCRIPTION', 'KEYWORDS[]',
#        'KEYWORDS_DATASET[]', 'METHODOLOGY_NOTES', 'ACCESS_SHARING_NOTES',
#        'SHORT_SOURCE_CITATION', 'FULL_SOURCE_CITATION', 'LICENSE',
#        'SUGGESTED_CITATION'],
#       dtype='object')
